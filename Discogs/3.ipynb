# %%
import requests
import pandas as pd
import json
import time
import numpy as np

# %%
formatos = pd.read_csv('Remplazar_gender.csv')

# %% [markdown]
# ## Rellenamos no descripcion en las filas de genero que no contenga info

# %%
formatos['gender'] = formatos['gender'].fillna("no description")

# %%
formatos['gender']
# Out:
# 0          electronic
# 1          electronic
# 2          electronic
# 3          electronic
# 4          electronic
#             ...
# 962    no description
# 963    no description
# 964    no description
# 965    no description
# 966    no description
# Name: gender, Length: 967, dtype: object

# %% [markdown]
# ## Quiero saber en la columna de album_format cuantos contienen 'album'

# %%
filtro_album = formatos[formatos['album_format'].str.contains('album', case=False, na=False)]

# %%
filtro_album
# Out:
#      artist_id              name    type                         album_name  \
# 582         19  Sound Associates  vendor  The Sounds Of The Young Tradition
# 955         28      Moonchildren  vendor                 Rapid Eye Movement
# 960         28      Moonchildren  vendor                   Tried To Be Good
#
#         descripcion  album_year    album_format  album_id  \
# 582  no description        1971       LP, Album   9641656
# 955  no description        2001  12", MiniAlbum     16921
# 960  no description        2001  12", MiniAlbum      9173
#
#                                                    uri  \
# 582  https://www.discogs.com/artist/19-Sound-Associ...
# 955     https://www.discogs.com/artist/28-Moonchildren
# 960     https://www.discogs.com/artist/28-Moonchildren
#
#                                           albums album_format_2  \
# 582  https://api.discogs.com/artists/19/releases            NaN
# 955  https://api.discogs.com/artists/28/releases          Vinyl
# ...

# %% [markdown]
# ## Remplazo los albums los 0s por varios, ya que si no tenia info la columna era porque eran mas de un tipo de formato. No se podía hacer webscrapping

# %%
formatos['album_format'] = formatos['album_format'].replace("0", "varios")

# %%
formatos.sample(10)
# Out:
#      artist_id              name    type  \
# 543         17       John Selway  artist
# 316          9      Care Company  vendor
# 385         13             Blaze  artist
# 689         21       Faze Action  artist
# 592         19  Sound Associates  vendor
# 888         26      Alexi Delano  artist
# 208          5        Heiko Laux  artist
# 776         24        Atom Heart  artist
# 74           3         Josh Wink  artist
# 752         23        Alex Hi-Fi  vendor
#
#                                       album_name  \
# 543                                     Untitled
# 316  Sonic Seducer Cold Hands Seduction Vol. XII
# 385                        The Blaze Tracks E.P.
# 689                               Stratus Energy
# 592                              Club Foundation
# 888                                 Too Far Gone
# 208                     Moonside Playground 2013
# 776             Volume 1 (The Singles 1991-2000)
# 74     A Higher State Of Wink's Works - Compiled
# ...

# %%
formatos.head()
# Out:
#    artist_id           name    type                   album_name  \
# 0          1  The Persuader  artist                         Kaos
# 1          1  The Persuader  artist  Snorkelmannen Ø Hans Vänner
# 2          1  The Persuader  artist           Stockholm By Night
# 3          1  The Persuader  artist              City Of Islands
# 4          1  The Persuader  artist                     Pleasure
#
#                                          descripcion  album_year album_format  \
# 0  electronic artist working out of stockholm, ac...        1997          10"
# 1  electronic artist working out of stockholm, ac...        1997          12"
# 2  electronic artist working out of stockholm, ac...        1997       varios
# 3  electronic artist working out of stockholm, ac...        1998       varios
# 4  electronic artist working out of stockholm, ac...        1998       varios
#
#    album_id                                             uri  \
# ...

# %% [markdown]
# ## Quiero que remplace los album por vinyl

# %%
formatos['album_format'] = formatos['album_format'].replace("album", "vinyl")

# %%
formatos
# Out:
#      artist_id           name    type  \
# 0            1  The Persuader  artist
# 1            1  The Persuader  artist
# 2            1  The Persuader  artist
# 3            1  The Persuader  artist
# 4            1  The Persuader  artist
# ..         ...            ...     ...
# 962         28   Moonchildren  vendor
# 963         28   Moonchildren  vendor
# 964         28   Moonchildren  vendor
# 965         28   Moonchildren  vendor
# 966         28   Moonchildren  vendor
#
#                                          album_name  \
# 0                                              Kaos
# 1                       Snorkelmannen Ø Hans Vänner
# 2                                Stockholm By Night
# 3                                   City Of Islands
# 4                                          Pleasure
# ..                                              ...
# 962                                   Chill House 7
# 963                                       Deepburnt
# ...

# %%
round(formatos['album_year'].mean())
# Out:
# 1969

# %% [markdown]
# ## Queremos quitar en la columna de año de album los que pongan 0.

# %%
formatos.album_year.value_counts()
# Out:
# album_year
# 1998    96
# 1999    77
# 1997    75
# 2001    69
# 1996    64
# 2000    60
# 2002    56
# 1995    41
# 2003    36
# 2006    31
# 2005    30
# 1994    29
# 2010    28
# 2004    25
# 1993    25
# 2007    22
# 2009    20
# 2013    16
# 0       16
# 2008    16
# 2012    15
# 2015    13
# 2014    13
# 2011    12
# 1992    12
# 2017    12
# 2016    11
# 2018     8
# 2019     7
# 2021     6
# 2022     4
# 2023     4
# 1991     4
# 1990     3
# 2020     3
# 1987     2
# 2024     1
# 1985     1
# 1986     1
# 1988     1
# 1971     1
# 1982     1
# Name: count, dtype: int64

# %% [markdown]
# ## Lo rellenamos por el año anterior

# %%
formatos['album_year'] = formatos['album_year'].replace(0, method='ffill')
# Out:
# /var/folders/cz/35gfl8ts1n39c5cfv2rn7pxw0000gn/T/ipykernel_67298/67660112.py:1: FutureWarning: The 'method' keyword in Series.replace is deprecated and will be removed in a future version.
#   formatos['album_year'] = formatos['album_year'].replace(0, method='ffill')

# %%
formatos.album_year.value_counts()
# Out:
# album_year
# 1998    96
# 1999    80
# 1997    75
# 2001    69
# 1996    64
# 2000    63
# 2002    56
# 1995    41
# 2003    37
# 2006    31
# 2005    30
# 2010    29
# 1994    29
# 2004    25
# 1993    25
# 2007    22
# 2009    22
# 2013    16
# 2008    16
# 2017    15
# 2012    15
# 2015    13
# 2014    13
# 1992    12
# 2011    12
# 2016    11
# 2018     8
# 2019     7
# 2023     7
# 2021     6
# 1991     4
# 2022     4
# 1990     3
# 2020     3
# 1987     2
# 1971     1
# 1985     1
# 1988     1
# 1986     1
# 2024     1
# 1982     1
# Name: count, dtype: int64

# %%
formatos.to_csv('formatos.csv', header=True, index= False)
